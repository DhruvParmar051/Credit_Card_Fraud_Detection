# %% [markdown]
# ### 📌 Credit Card Fraud Detection
#
# ----

# %% [markdown]
# 🔄 Life Cycle of Machine Learning Project
# 1. Understanding the Problem Statement
# 2. Data Collection
# 3. Data Checks to Perform
# 4. Exploratory Data Analysis (EDA)
# 5. Data Preprocessing
# 6. Model Training & Selection
# 7. Evaluation & Interpretation
# 8. Deployment & Future Enhancements
#
# ---

# %% [markdown]
# 🚀 Understanding the Problem
#
# Credit card fraud is a growing concern in the financial industry.
# This project aims to detect fraudulent transactions using machine learning techniques.
# We will analyze various transaction features and train models to classify transactions as 'Fraudulent' or 'Legitimate'.
#
# ----

# %% [markdown]
# 📊 Data Collection
# - Dataset Source: [Kaggle - Credit Card Fraud Detection](https://www.kaggle.com/mlg-ulb/creditcardfraud)
# - The dataset consists of 284,807 transactions with 30 features, including:
#   - `Time`: Time elapsed since the first transaction.
#   - `V1` to `V28`: Features transformed using PCA.
#   - `Amount`: Transaction amount.
#   - `Class`: Target variable (0 = Legitimate, 1 = Fraudulent).
#
# ---

# %% [markdown]
# ✅ Data Checks to Perform
# - Check for missing values
# - Check for duplicates
# - Identify data types
# - Analyze distribution of target classes (Fraud vs. Legitimate)
# - Identify outliers and imbalanced data
#
# ----

# %% [markdown]
# 🛠️ Data Preprocessing
# - Handling missing values (if any)
# - Scaling numerical features using StandardScaler
# - Handling imbalanced data using techniques like SMOTE
# - Feature selection using PCA or Mutual Information
#
# ----

# %% [markdown]
# 📈 Exploratory Data Analysis (EDA)
# - Visualizing class distribution (fraud vs. legitimate)
# - Analyzing correlations** between features
# - Understanding time-based patterns
# - Identifying high-risk transaction features

# %% [markdown]
# ----

# %% [markdown]
# 1)  Data Collection

# %%
# import Required Packages

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
csv_path = "data\creditcard.csv"
credit_df = pd.read_csv(csv_path)
print(credit_df.head())
print(credit_df.shape)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %% [markdown]
# 2. Data Checks to Perform

# %%
# list the columns of credit_df
print(credit_df.columns)
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
# Check for missing values
credit_df.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# check for duplicate
credit_df.duplicated().sum()
# Out:
# 1081

# %%
# remove duplicates
credit_df = credit_df.drop_duplicates()

# %%
# check for data type
credit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 283726 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    283726 non-null  float64
#  1   V1      283726 non-null  float64
#  2   V2      283726 non-null  float64
#  3   V3      283726 non-null  float64
#  4   V4      283726 non-null  float64
#  5   V5      283726 non-null  float64
#  6   V6      283726 non-null  float64
#  7   V7      283726 non-null  float64
#  8   V8      283726 non-null  float64
#  9   V9      283726 non-null  float64
#  10  V10     283726 non-null  float64
#  11  V11     283726 non-null  float64
#  12  V12     283726 non-null  float64
#  13  V13     283726 non-null  float64
#  14  V14     283726 non-null  float64
#  15  V15     283726 non-null  float64
#  16  V16     283726 non-null  float64
#  17  V17     283726 non-null  float64
#  18  V18     283726 non-null  float64
#  19  V19     283726 non-null  float64
# ...

# %%
# check for unique values
credit_df.nunique()
# Out:
# Time      124592
# V1        275663
# V2        275663
# V3        275663
# V4        275663
# V5        275663
# V6        275663
# V7        275663
# V8        275663
# V9        275663
# V10       275663
# V11       275663
# V12       275663
# V13       275663
# V14       275663
# V15       275663
# V16       275663
# V17       275663
# V18       275663
# V19       275663
# V20       275663
# V21       275663
# V22       275663
# V23       275663
# V24       275663
# V25       275663
# V26       275663
# V27       275663
# V28       275663
# Amount     32767
# Class          2
# dtype: int64

# %%
# Check for statistical description
credit_df.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean    94811.077600       0.005917      -0.004135       0.001613
# std     47481.047891       1.948026       1.646703       1.508682
# min         0.000000     -56.407510     -72.715728     -48.325589
# 25%     54204.750000      -0.915951      -0.600321      -0.889682
# 50%     84692.500000       0.020384       0.063949       0.179963
# 75%    139298.000000       1.316068       0.800283       1.026960
# max    172792.000000       2.454930      22.057729       9.382558
#
#                   V4             V5             V6             V7  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean       -0.002966       0.001828      -0.001139       0.001801
# std         1.414184       1.377008       1.331931       1.227664
# min        -5.683171    -113.743307     -26.160506     -43.557242
# ...

# %% [markdown]
# 4. Exploring Data ( Visualization )

# %%
# Fraud vs Non-Fraud Transactions
sns.countplot(data=credit_df, x='Class')
plt.title("Fraud vs Non-Fraud Transactions")
plt.xticks([0, 1], ['Non-Fraud', 'Fraud'])
plt.show()

# %%
# Transaction Amount Distribution (Fraud vs Non-Fraud)
sns.histplot(data=credit_df, x='Amount', hue='Class', bins=50, kde=True)
plt.xscale('log')  # Log scale helps if Amount has a large range
plt.title("Transaction Amount Distribution (Fraud vs Non-Fraud)")
plt.show()

# %%
# Transaction Amounts by Class
sns.boxplot(data=credit_df, x='Class', y='Amount')
plt.yscale('log')  # Helps visualize outliers better
plt.title("Transaction Amounts by Class")
plt.show()

# %%
# Feature Correlation Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(credit_df.corr(), cmap='coolwarm', annot=False)
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
# Transaction Amount Over Time (Fraud vs Non-Fraud)
sns.scatterplot(data=credit_df, x='Time', y='Amount', hue='Class', alpha=0.5)
plt.xscale('log')
plt.title("Transaction Amount Over Time (Fraud vs Non-Fraud)")
plt.show()

# %%
# Pie Chart: Fraud vs Non-Fraud Transactions
# Count occurrences of each class
fraud_counts = credit_df['Class'].value_counts()

# Labels and colors
labels = ['Non-Fraud', 'Fraud']
colors = ['lightblue', 'red']

# Plot Pie Chart
plt.figure(figsize=(6, 6))
plt.pie(fraud_counts, labels=labels, autopct='%1.2f%%', colors=colors, startangle=45, explode=[0, 0.1])
plt.title("Fraud vs Non-Fraud Transactions")
plt.show()
